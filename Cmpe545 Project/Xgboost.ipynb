# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_fscore_support,accuracy_score,recall_score,confusion_matrix,precision_score,f1_score

# %%
def read_features(csv_path_prefix):
    train=pd.read_csv(csv_path_prefix+"train.csv")
    train_X=train.iloc[:,0:len(train.columns)-2]
    train_Y=train.Class.values
    val=pd.read_csv(csv_path_prefix+"val.csv")
    val_X=val.iloc[:,0:len(val.columns)-2]
    val_Y=val.Class.values
    return train_X,val_X,train_Y,val_Y
def print_metrics(Y,predictions):
    acc=accuracy_score(Y,predictions)
    war=recall_score(Y,predictions,average="weighted")
    wap=precision_score(Y,predictions,average="weighted")
    waf1=f1_score(Y,predictions,average="weighted")
    print("Accuracy: ",acc)
    print("Recall: ",war)
    print("Precision: ",wap)
    print("F1-Score: ",waf1)
    a=confusion_matrix(Y,predictions)
    print("{0:.2f}\t{1:.2f}\t{2:.2f}\t{3:.2f}".format(acc*100,war*100,wap*100,waf1*100))
    return a

# %%
# all Y's are same
train_30_X,val_30_X,train_30_Y,val_30_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_30_256")
train_45_X,val_45_X,train_45_Y,val_45_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_45_256")
train_65_X,val_65_X,train_65_Y,val_65_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_65_256")
train_70_X,val_70_X,train_70_Y,val_70_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_70_256")
train_75_X,val_75_X,train_75_Y,val_75_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_75_256")

train_80_X,val_80_X,train_80_Y,val_80_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_80_256")

train_85_X,val_85_X,train_85_Y,val_85_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_85_256")
train_90_X,val_90_X,train_90_Y,val_90_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_90_256")
train_95_X,val_95_X,train_95_Y,val_95_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_95_256")

# %%
train_X=np.concatenate((train_30_X,train_45_X,train_65_X,train_75_X,train_85_X,train_95_X),axis=1)
val_X=np.concatenate((val_30_X,val_45_X,val_65_X,val_75_X,val_85_X,val_95_X),axis=1)
dTrain=xgb.DMatrix(train_X,train_30_Y)
dVal=xgb.DMatrix(val_X,val_30_Y)
param = {
         'learning_rate': 0.5,        
          'max_depth':8,

         'objective': 'multi:softmax', 'silent': True,
         'num_class':3,
         'tree_method':'gpu_hist',
         'eval_metric:':'merror'}
num_round = 4000
bst = xgb.train(param, dTrain, num_round,evals=[(dTrain,'train'),(dVal,'val')], early_stopping_rounds=10)

print_metrics(val_30_Y,predictions=bst.predict(dVal))

# %%
train_75_X,val_75_X,train_75_Y,val_75_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_90_128")
train_60_X,val_60_X,train_60_Y,val_60_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_45_128")
train_45_X,val_45_X,train_45_Y,val_45_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_60_128")
train_30_X,val_30_X,train_30_Y,val_30_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_75_128")
# all Y's are same

train_X=np.concatenate((train_30_X,train_45_X,train_60_X,train_75_X),axis=1)
val_X=np.concatenate((val_30_X,val_45_X,val_60_X,val_75_X),axis=1)

dTrain=xgb.DMatrix(train_X,train_30_Y)
dVal=xgb.DMatrix(val_X,val_30_Y)
param = {'booster':'dart',
         'learning_rate': 0.1,
         'objective': 'multi:softmax', 'silent': True,
         'num_class':3,
         'tree_method':'gpu_hist',
         'eval_metric:':'mlogloss'}
num_round = 4000
bst = xgb.train(param, dTrain, num_round,evals=[(dTrain,'train'),(dVal,'val')], early_stopping_rounds=50)
predictions=bst.predict(dVal)
print_metrics(val_30_Y,predictions)

# %%
val_X.shape

# %%
# all Y's are same
train_30_X,val_30_X,train_30_Y,val_30_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_30_256")
train_45_X,val_45_X,train_45_Y,val_45_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_45_256")
train_65_X,val_65_X,train_65_Y,val_65_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_65_256")
train_70_X,val_70_X,train_70_Y,val_70_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_70_256")
train_75_X,val_75_X,train_75_Y,val_75_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_75_256")

train_80_X,val_80_X,train_80_Y,val_80_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_80_256")

train_85_X,val_85_X,train_85_Y,val_85_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_85_256")
train_90_X,val_90_X,train_90_Y,val_90_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_90_256")
train_95_X,val_95_X,train_95_Y,val_95_Y=read_features("features/gru/0.16_0.08/upsample_2layer_256_95_256")







train_X=np.concatenate((train_30_X,train_45_X,train_60_X,train_65_X,train_70_X,train_75_X,train_80_X,train_85_X,train_90_X,train_95_X),axis=1)
val_X=np.concatenate((val_30_X,val_45_X,val_60_X,val_65_X,val_70_X,val_75_X,val_80_X,val_85_X,val_90_X,val_95_X),axis=1)

dTrain=xgb.DMatrix(train_X,train_30_Y)
dVal=xgb.DMatrix(val_X,val_30_Y)
param = {'booster':'dart',
         'learning_rate': 1,
         'objective': 'multi:softmax', 'silent': True,
         'num_class':3,
        
         'eval_metric:':'merror'}
num_round = 4000
bst = xgb.train(param, dTrain, num_round,evals=[(dTrain,'train'),(dVal,'val')], early_stopping_rounds=10)
predictions=bst.predict(dVal)
print_metrics(val_30_Y,predictions)

# %%
train_X=np.concatenate((train_65_X,train_75_X,train_80_X,train_90_X,train_95_X),axis=1)
val_X=np.concatenate((val_65_X,val_75_X,val_80_X,val_90_X,val_95_X),axis=1)

dTrain=xgb.DMatrix(train_X,train_30_Y)
dVal=xgb.DMatrix(val_X,val_30_Y)
param = {
         'learning_rate':0.01,
        'max_depth':8,
         'objective': 'multi:softmax', 'silent': True,
         'num_class':3,
         'tree_method':'gpu_hist',
         'eval_metric:':'merror'}
num_round = 4000
bst = xgb.train(param, dTrain, num_round,evals=[(dTrain,'train'),(dVal,'val')], early_stopping_rounds=10)
predictions=bst.predict(dVal)
print_metrics(val_30_Y,predictions)

# %%
# Out:
# [0]	train-merror:0.12069	val-merror:0.6
# Multiple eval metrics have been passed: 'val-merror' will be used for early stopping.
#
# Will train until val-merror hasn't improved in 10 rounds.
# [1]	train-merror:0.020936	val-merror:0.6
# [2]	train-merror:0	val-merror:0.572222
# [3]	train-merror:0	val-merror:0.588889
# [4]	train-merror:0	val-merror:0.572222
# [5]	train-merror:0	val-merror:0.572222
# [6]	train-merror:0	val-merror:0.572222
# [7]	train-merror:0	val-merror:0.588889
# [8]	train-merror:0	val-merror:0.588889
# [9]	train-merror:0	val-merror:0.583333
# [10]	train-merror:0	val-merror:0.588889
# [11]	train-merror:0	val-merror:0.566667
# [12]	train-merror:0	val-merror:0.55
# [13]	train-merror:0	val-merror:0.555556
# [14]	train-merror:0	val-merror:0.566667
# [15]	train-merror:0	val-merror:0.572222
# [16]	train-merror:0	val-merror:0.583333
# [17]	train-merror:0	val-merror:0.572222
# [18]	train-merror:0	val-merror:0.561111
# [19]	train-merror:0	val-merror:0.572222
# ...

# %%
# all Y's are same
train_30_X,val_30_X,train_30_Y,val_30_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_30_128")
train_45_X,val_45_X,train_45_Y,val_45_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_45_128")
train_65_X,val_65_X,train_65_Y,val_65_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_65_128")
train_70_X,val_70_X,train_70_Y,val_70_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_70_128")
train_75_X,val_75_X,train_75_Y,val_75_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_75_128")

train_80_X,val_80_X,train_80_Y,val_80_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_80_128")

train_85_X,val_85_X,train_85_Y,val_85_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_85_128")
train_90_X,val_90_X,train_90_Y,val_90_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_90_128")
train_95_X,val_95_X,train_95_Y,val_95_Y=read_features("features/gru/0.32_0.16/upsample_2layer_64_95_128")






train_X=np.concatenate((train_80_X,train_95_X),axis=1)
val_X=np.concatenate((val_80_X,val_95_X),axis=1)
dTrain=xgb.DMatrix(train_X,train_30_Y)
dVal=xgb.DMatrix(val_X,val_30_Y)
param = {'booster':'dart',
         'learning_rate': 0.1,
         'objective': 'multi:softmax', 'silent': True,
         'num_class':3,
         'tree_method':'gpu_hist',
         'eval_metric:':'merror'}
num_round = 4000
bst = xgb.train(param, dTrain, num_round,evals=[(dTrain,'train'),(dVal,'val')], early_stopping_rounds=50)

print_metrics(val_30_Y,predictions=bst.predict(dVal))
